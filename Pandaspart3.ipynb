# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Satyam\Downloads\Bengaluru_House_Data.csv')

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.isnull()
# Out:
#        area_type  availability  location   size  society  total_sqft   bath  \
# 0          False         False     False  False    False       False  False
# 1          False         False     False  False    False       False  False
# 2          False         False     False  False    False       False  False
# 3          False         False     False  False    False       False  False
# 4          False         False     False  False     True       False  False
# ...          ...           ...       ...    ...      ...         ...    ...
# 13315      False         False     False  False    False       False  False
# 13316      False         False     False  False     True       False  False
# 13317      False         False     False  False    False       False  False
# 13318      False         False     False  False    False       False  False
# 13319      False         False     False  False     True       False  False
#
#        balcony  price
# 0        False  False
# ...

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5501
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
len(df)
# Out:
# 13320

# %%
df.shape[0]
# Out:
# 13320

# %%
# per of missing data in dataframe.
# per of missing data in society col.

df.shape[0]
# Out:
# 13320

# %%
df.isnull().sum().sum()
# Out:
# 6200

# %%
per_of_null_data = (df.isnull().sum().sum()/df.shape[0])*100

# %%
per_of_null_data
# Out:
# 46.546546546546544

# %%
per_of_null_data_in_society = (df['society'].isnull().sum()/df.shape[0])*100

# %%
per_of_null_data_in_society
# Out:
# 41.2987987987988

# %%
# ignore
# del------>
# random

# mean
# median
# mode

df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5501
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df['society'].dtype
# Out:
# dtype('O')

# %%
df.society
# Out:
# 0        Coomee
# 1        Theanmp
# 2         @@@@@@
# 3        Soiewre
# 4            NaN
#           ...
# 13315    ArsiaEx
# 13316        NaN
# 13317    Mahla T
# 13318    SollyCl
# 13319        NaN
# Name: society, Length: 13320, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7819 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.society.isnull().sum()
# Out:
# 5501

# %%
df.society.mode()
# Out:
# 0    GrrvaGr
# dtype: object

# %%
# fillna method


df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2   @@@@@@       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df['society']
# Out:
# 0        Coomee
# 1        Theanmp
# 2         @@@@@@
# 3        Soiewre
# 4            NaN
#           ...
# 13315    ArsiaEx
# 13316        NaN
# 13317    Mahla T
# 13318    SollyCl
# 13319        NaN
# Name: society, Length: 13320, dtype: object

# %%
# replace
df.replace(to_replace = '2 BHK',value = 'ML')
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0             ML  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df1 = df.replace('@@@@@@','NaN',inplace = True)

# %%
df.shape
# Out:
# (13320, 9)

# %%
# ffill
# bfill
# pad
# backfill

df['society'].fillna(method='ffill',inplace = True)

# %%
df.society.isnull().sum()
# Out:
# 0

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df['society'].fillna(method='backfill',inplace = True)

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
# task 1 -----> try to find a top 5 house wrt to price
# 1. price would be max
# 2. price would be min.

# task 2 ----> try to find a house where bath is min 2 and price would be less
# than 200$.

# %%
df[df['price']== df['price'].max()].head(9)
# Out:
#         area_type   availability        location        size  society  \
# 13067  Plot  Area  Ready To Move  Defence Colony  10 Bedroom  SSestth
#
#       total_sqft  bath  balcony   price
# 13067       7150  13.0      NaN  3600.0

# %%
# max price --- top 5

df.price.median()
# Out:
# 72.0

# %%
df[df['price'] > df.price.median()].sort_values('price',ascending=False).head()
# Out:
#                   area_type   availability         location        size  \
# 13067            Plot  Area  Ready To Move   Defence Colony  10 Bedroom
# 11080  Super built-up  Area         18-Jan      Ashok Nagar       4 BHK
# 13200            Plot  Area  Ready To Move   Defence Colony   6 Bedroom
# 11763            Plot  Area  Ready To Move  Sadashiva Nagar   5 Bedroom
# 3180   Super built-up  Area  Ready To Move  Shanthala Nagar       5 BHK
#
#        society total_sqft  bath  balcony   price
# 13067  SSestth       7150  13.0      NaN  3600.0
# 11080  Neise P       8321   5.0      2.0  2912.0
# 13200  Sririth       8000   6.0      3.0  2800.0
# 11763  Pruthg        9600   7.0      2.0  2736.0
# 3180   Kierser       8321   5.0      3.0  2700.0

# %%
# min price

df[df['price'] < df.price.median()].sort_values('price').head()
# Out:
#                   area_type          availability            location   size  \
# 10526  Super built-up  Area         Ready To Move  Yelahanka New Town  1 BHK
# 11569            Plot  Area  Immediate Possession          Hosur Road    NaN
# 8594         Built-up  Area         Ready To Move          Chandapura  1 BHK
# 11091        Built-up  Area         Ready To Move            Attibele  1 BHK
# 12579  Super built-up  Area         Ready To Move          Chandapura  1 BHK
#
#        society total_sqft  bath  balcony  price
# 10526  KHatsFl        284   1.0      1.0   8.00
# 11569  AVeldun       1350   NaN      NaN   8.44
# 8594   Amazaa         450   1.0      1.0   9.00
# 11091  DSnjh S        410   1.0      1.0  10.00
# 12579  Puveshe        410   1.0      1.0  10.00

# %%
df.price.min()
# Out:
# 8.0

# %%
# task 2 ----> try to find a house where bath is min 2 and price would be less
# than 200$.


df[(df['bath']>=2)  & (df['price']<200)][['location','area_']].head(10)
# Out:
# 0     Electronic City Phase II
# 1             Chikka Tirupathi
# 2                  Uttarahalli
# 3           Lingadheeranahalli
# 4                     Kothanur
# 5                   Whitefield
# 8                 Marathahalli
# 10                  Whitefield
# 12          7th Phase JP Nagar
# 13                   Gottigere
# Name: location, dtype: object
